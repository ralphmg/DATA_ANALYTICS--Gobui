# %% [markdown]
# Data: https://archive.ics.uci.edu.
#
# Instruction: Choose a dataset and perform a data storytelling, choose the proper data visualization, do not use words, your graphs must tell a story.

# %%
import matplotlib.pyplot as plt

# Convert 'Date' and 'Time' columns to datetime format
data['DateTime'] = pd.to_datetime(data['Date'] + ' ' + data['Time'])

# Plotting occupancy count over time
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['Room_Occupancy_Count'], color='blue')
plt.title('Room Occupancy Over Time')
plt.xlabel('Date')
plt.ylabel('Occupancy Count')
plt.grid(True)
plt.show()

# Plotting temperature in different sensors over time
plt.figure(figsize=(12, 6))
for i in range(1, 5):
    plt.plot(data['DateTime'], data[f'S{i}_Temp'], label=f'Sensor {i}')
plt.title('Temperature Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()

# Plotting CO2 levels over time
plt.figure(figsize=(12, 6))
plt.plot(data['DateTime'], data['S5_CO2'], color='green')
plt.title('CO2 Levels Over Time')
plt.xlabel('Date')
plt.ylabel('CO2 Levels')
plt.grid(True)
plt.show()

# Plotting Light intensity over time
plt.figure(figsize=(12, 6))
for i in range(1, 5):
    plt.plot(data['DateTime'], data[f'S{i}_Light'], label=f'Sensor {i}')
plt.title('Light Intensity Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Light Intensity')
plt.legend()
plt.grid(True)
plt.show()

# Plotting Sound levels over time
plt.figure(figsize=(12, 6))
for i in range(1, 5):
    plt.plot(data['DateTime'], data[f'S{i}_Sound'], label=f'Sensor {i}')
plt.title('Sound Levels Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Sound Levels')
plt.legend()
plt.grid(True)
plt.show()

# Plotting PIR sensor activity over time
plt.figure(figsize=(12, 6))
for i in range(6, 8):
    plt.plot(data['DateTime'], data[f'S{i}_PIR'], label=f'Sensor {i}')
plt.title('PIR Sensor Activity Over Time')
plt.xlabel('Date')
plt.ylabel('PIR Sensor Output')
plt.legend()
plt.grid(True)
plt.show()

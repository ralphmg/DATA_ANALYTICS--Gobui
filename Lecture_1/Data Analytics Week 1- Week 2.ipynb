# %% [markdown]
# $\textbf{Difference Between Data Science and Data Analytics}$
#
# 1. $\textbf{Objective and Scope:}$
#
# Data science:
#
#     - broader in scope.
#     - Involves creating new ways of modeling and understanding raw data.
#     - Focus on designing and constructing new processes for data modeling.
#     - Rooted from computational statistics
#
# Data analytics:
#
#     - Focused more on processing and performing statistical analysis on existing datasets.
#     - Data analysts often use established processes to uncover useful information and to help organizations make informed decisions.
#     - Rooted form inferential statistics
#
#
# 2. $\textbf{Tools and Techniques:}$
#
# Data science:
#
#     - Capable of performing mathematical and statistical modelling for non-tractable probability distribution (common in high dimensional data).
#     - Use a wide array of advanced analytical techniques and algorithms, including machine learning, predictive modeling, data mining, and high dimensional data.
#
#
# Data analytics:
#
#     - Focused more on common and well established probability distributions.
#     - Primarily focus on parsing through existing data and interpreting it.
#     - Use statistical tools and techniques to analyze, visualize, and present data.
#
# 3. $\textbf{Skill Set and Background:}$
#
# Data Science:
#
#     - Typically requires a stronger background in mathematics, computer science and statistics.
#     - Needs to be skilled in coding to translate statistical models into working algorithms.
#
# Data Analytics:
#
#     - Requires stronger skills in mathematics and statistics then in compuyter science.
#     - Data analysts need to be adept at data cleaning, data visualization, and using statistical methods to analyze data.
#
# 4. $\textbf{End Goals:}$
#
# Data Science:
#
#     - The end goal is often to create new ways of modeling data.
#     - It's more about building new algorithms and predictive models to predict future events or to discover patterns that were previously unknown.
#
# Data Analytics:
#
#     - The focus is on solving problems related to the current data.
#     - Analysts work to uncover trends and insights that are used for immediate decision-making.
#
# 5. $\textbf{Nature of Work:}$
#
# Data Science:
#
#     - More exploratory and experimental (developing new or novel methods).
#     - Data scientists work on larger sets of data to discover what questions can be asked and answered (You have a model, to fit to an unknown business problem).
#
# Data Analytics:
#
#     - Focused on answering specific questions and helping to solve specific problems.
#     - It's generally more straightforward and less experimental than data science (You are given a business problem you need to fit a model).

# %% [markdown]
# $\textbf{Probability Distribution}$

# %% [markdown]
# 1. A random experiment: You have the same experiment, the same method but you always get a different result.
# 2. A random event: generated by a random process, that is the outcome maybe the desired result or not.
# 3. A random variable: A function that assigns a value to each outcome example head=1, tails=0.

# %% [markdown]
# $\textbf{Discrete Distributions}$
# - Models a countably finite or countably infinite distinct values.
# - Let $Y$ be a discrete random variable with a probability function $f(y)$. Then the expected value of $Y$, $E(Y)$ is defined as:
# \begin{equation}
# E(Y) = \Sigma_{y}yf(y)
# \end{equation}
#
# Example:
# \begin{equation}
# \begin{bmatrix}
# \begin{array}{c|c}
# y & p(y) \\
# 0 & \frac{1}{4} \\
# 1 & \frac{1}{2} \\
# 2 & \frac{1}{4} \\
# \end{array}
# \end{bmatrix}
# \end{equation}
#
# \begin{equation}
# E(Y) = \Sigma_{y}yf(y) = (0)(\frac{1}{4}) + (1) (\frac{1}{2}) + (2) (\frac{1}{4}) = 1
# \end{equation}
#
# - The variance of a discrete function
# \begin{gather}
# V(Y) = E[(Y-E[Y])^{2}] = E[(Y-E[Y])(Y-E[Y])] = E[(Y)^2 -2(Y)(E[Y])+E[Y]^{2}]
# \\
# = E[Y^{2}] - 2(E[Y])(E[Y])+E[Y]^{2} = E[Y^{2}] - E[Y]^{2}
# \end{gather}
#
# \begin{gather}
# V(Y) = E[(Y - E[Y])^2] = \Sigma_{y}(y-E[y])^2f(y)
# \\
# = (0-1)^2(\frac{1}{4}) + (1-1)^2 (\frac{1}{2}) + (2-1)^2 (\frac{1}{4})
# \\
# = (-1)^2(\frac{1}{4}) + (0)^2 (\frac{1}{2}) + (1)^2 (\frac{1}{4})
# \\
# = (1)(\frac{1}{4}) + (0) (\frac{1}{2}) + (1) (\frac{1}{4})
# \\
# = (1)(\frac{1}{4}) + (1) (\frac{1}{4}) = \frac{1}{8}
# \end{gather}

# %% [markdown]
# $\textbf{Binomial Probability Distribution}$

# %% [markdown]
# A Binomial process has the following properties:
#
# 1. The process consists of a fixed number of identical trials, $n$.
#
# 2. Each trial results in either a success, $S$, or a failure, $F$.
#
# 3. The probability of a sucess on a single trial is $p$ which remains the same from trial to trial.
#
# 4. The probability of a failure is equal to $q=1-p$.
#
# 5. Trials are independent.
#
# 6. The random variable of interest is $Y$, representing the number of successes observed during the n trials.
#
# 7. $p(y) = \begin{pmatrix}n \\y \end{pmatrix}p^y(1-p)^{n-y}$
#
# 8. The mean value $E[Y] = np$ and the variance is $Var[Y] = npq$

# %%
from scipy.stats import binom 
import plotly.io as pio
pio.renderers.default = 'iframe'
import plotly.graph_objects as go
# setting the values 
# of n and p 
n = 10
p = 0.1
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
# plotting the graph  
fig = go.Figure([go.Bar(x=r_values, y=dist)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_5.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from scipy.stats import binom 
import plotly.graph_objects as go
# setting the values 
# of n and p 
n = 10
p = 0.5
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
fig = go.Figure([go.Bar(x=r_values, y=dist)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_2.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from scipy.stats import binom 
import plotly.graph_objects as go
# setting the values 
# of n and p 
n = 10
p = 0.9
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
fig = go.Figure([go.Bar(x=r_values, y=dist)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_3.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ${Real World Application}$
#
# An eletrcial companyt hired you as a data scientist, the company was wondering if there current pilot batch of electronic parts is good for public consumption. Currently a lot of 5,000 electrical fuses is assumed to contain 5% defectives. If a sample of 5 fuses is tested, find the probability of observing at least one is defective. Is 5% too high?
#
# Given:
# n = 5
# Success = 0 (by the condition that at least 1 is defective).
#
# $P(failed) = 1 - success = 1 - working \ condition$
#
# $p(y) = 1-p(0) = 1-\begin{pmatrix}5 \\ 0 \end{pmatrix} p^0(1-p)^5 = 1 - (\frac{5!}{0!(5-0)!})(0.05)^0(1-0.05)^{5-0} = 1-(0.95)^5 = 0.226$

# %%
from scipy.stats import binom 
import plotly.graph_objects as go
# setting the values 
# of n and p 
n = 5
p = 0.05
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ]

# plotting the graph  
fig = go.Figure(data=[
    go.Bar(x=r_values, y=dist, name = "Prob.")
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_4.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Geometric Probability Distribution}$

# %% [markdown]
# - Is similar to the Binomial distribution except it measures the of the probabaility of the 1st success.
# - $p(y) = q^{y-1}p$
# - Mean value, $E[Y] = \frac{1}{p}$
# - Variance, $Var[Y] = \frac{1-p}{p^2}$

# %% [markdown]
# $\textbf{Example:}$
# Suppose that the probability of an engine malfunction during any one-hour period is $p = 0.02$. Find the probability that a given engine will survive two hours.
#
# $P(survive \ two \ hours) = 1 - \Sigma_{y=1}^2p(y) = 1 - [(0.98)^{1-1}(0.02)+0.98)^{2-1}(0.02)]
#  = 1-[(0.02)+(0.98)(0.02)] = 0.9604$

# %% [markdown]
# $\textbf{Negative Binomial Probability Distribution}$

# %% [markdown]
# - While the geometric probability distribution handles the case where we are intereste in knowing the number of trials of the first success, the negative binomial is focused on knowing the number of trial on the 2nd, 3rd, 4th, 5th,etc. success.
# - Given $y-1$ trials with $r-1$ success, where $y$ is equal to the number of trial on which the $r^{th}$ success occurs ($r = 2,3,4,5,...$)
# - $p(y) = \begin{pmatrix}y-1 \\ r-1 \end{pmatrix} p^rq^{y-r}$
# - The expected value is $E[Y] = \frac{r}{p}$
# - The variance is $V(Y)=\frac{r(1-p)}{p^2}$

# %% [markdown]
# $\textbf{Poisson Probability distribution}$

# %% [markdown]
# - Modelling rare events that occur in space, time, and volume, or any other dimension.
# - The rare events is represented by the random variable $Y$.
# - A paramter $\lambda$ is the average value of $Y$.
# - This is indutrially used to models any forms of accidents (motor, industrial, etc.)
# - $p(y) = \frac{\lambda^y}{y!}e^{-\lambda} \ \forall \lambda>0 \, \  and \ y\geq0$
# - $E[Y]=V[Y]=\lambda$

# %% [markdown]
# $\textbf{Example:}$ A certain type of tree has seedlings randomly dispersed in a large area, with the mean density of seedlings being approximately five seed per square yard. If a forester randomly locates ten 1-square yard sampling regions in the area, find the probability that none of the regions will contain seedlings
#
# Solution:
#
# - $\lambda$ = 5
# - $P(Y=0)=\frac{\lambda^y}{y!}e^{-\lambda} = \frac{5^0}{0!}e^{-5} = 0.006738 = 0.6738\%$

# %%
from scipy.stats import poisson
import numpy as np
import plotly.graph_objects as go
x = np.arange(0, 10, 0.5)
y = poisson.pmf(x, mu=5)
fig = go.Figure([go.Bar(x=x, y=y)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_5.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Continuous Probability Function}$

# %% [markdown]
# $\textbf{Review of Differential Calculus}$
#
# 1. $\frac{d(a)}{dx} = d(a) = 0$
#
# 2. $\frac{d(x^n)}{dx} = d(x^n) = n x^{n-1}$
#
# 3. $\frac{d(a \cdotp x^n)}{dx} = a \cdotp d(x^n) = a \cdotp n x^{n-1}$
#
# Let $U$ and $V$ be functions of $x$ s.t. $U \neq V$.
#
# 1. $\frac{d(U)}{dx} = d(U)$
#
# 2. $\frac{d(a \cdotp U)}{dx} = a \cdotp d(U)$
#
# 3. $\frac{d(U + V)}{dx} = d(U + V) = d(U) + d(V)$
#
# 4. $\frac{d(U \cdotp V)}{dx} = d(U \cdotp V) = U \cdotp d(V) + V \cdotp d(U)$
#
# 5. $\frac{d(\frac{U}{V})}{dx} = d(\frac{U}{V}) = \frac{V \cdotp d(U) - U \cdotp d(V)}{V^2}$
#
# 6. $\frac{d(U^n)}{dx} = d(U^n) = n \cdotp U^{n-1} d(U)$
#
# 7. $\frac{d(e^{U})}{dx} = d(e^{U}) = e^U d(U)$
#
# 8. $\frac{d(a^{U})}{dx} = d(a^{U}) = \ln(a) \cdotp a^U \cdotp d(U)$
#
# 9. $\frac{d(\ln{U})}{dx} = d(\ln{U}) = \frac{1}{U} d(U)$
#
# 10. $\frac{d(\log_{a} U)}{dx} = d(d(\log_{a} U)) = \log_{a}(e) \cdotp \frac{1}{U} \cdotp d(U)$

# %% [markdown]
# $\textbf{Review of Integral Calculus}$
#
# https://www.physics.umd.edu/hep/drew/IntegralTable.pdf

# %% [markdown]
# $\textbf{Uniform Distribution}$
#
# - If $\theta_1 < \theta_2$, a random variable, $Y$, is said to have a continuous uniform probability distribution on the interval $(\theta_1, \theta_2) \iff$ the density of $Y$ if
#
# \begin{gather}
# f(y) = \begin{cases}
#       \frac{1}{\theta_2 - \theta_1}, & \text{if}\ \theta_1 \leq y \leq \theta_2 \\
#       0, & \text{otherwise}
#     \end{cases}
# \end{gather}
#
# - $E(Y) = \frac{\theta_1 - \theta_2}{2}$
#
# - $V(Y) = \frac{(\theta_1 - \theta_2)^2}{2}$

# %%
from scipy.stats import uniform
import numpy as np
import plotly.graph_objects as go

#creating an array of values between
#-3 to 8 with a difference of 0.1
x = np.arange(-3, 8, 0.1)
   
y = uniform.pdf(x, 0, 5)

fig = go.Figure([go.Bar(x=x, y=y)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Gaussian (Normal) Distribution}$
#
# - The most common continuous probability distribution.
#
# - Known for its bell shaped curve.
#
# - A random variable $Y$ is normally distributed $\iff \ for \  \sigma>0, \ and \ -\infty< \mu < \infty$:
#
# \begin{gather}
# f(y) = \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(y-\mu)^2}{2\sigma^2}}, \ \forall \ -\infty < y < \infty
# \end{gather}
#
# - $E[Y] = \mu$, $V[Y] = \sigma^2$

# %% [markdown]
# $\textbf{Deriving the Mean of a Gaussian Distribution by Maximum Likelihood Estimation}$
#
# - Given a i.i.d R.V. $Y$ s.t. $Y = {y_1, y_2, ...., y_n}$
#
# \begin{gather}
# f(y) = \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(y-\mu)^2}{2\sigma^2}}, \forall -\infty < y < \infty
# \\
# \\
# \Pi_i^n (f(y_i)) = \Pi_i^n \begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(y_i-\mu)^2}{2\sigma^2}} \end{pmatrix}
# \\
# \\
# = \begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}^n \begin{pmatrix}e^{-\frac{(y_i-\mu)^2}{2\sigma^2}}\end{pmatrix}^n
# \\
# \\
# = \begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}^n \begin{pmatrix}e^{-\Sigma_i^n \frac{(y_i-\mu)^2}{2\sigma^2}}\end{pmatrix}
# \\
# \\
# \ln{\Pi_i^n (f(y_i))} = \ln \begin{bmatrix}{\begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}^n \begin{pmatrix}e^{-\Sigma_i^n \frac{(y_i-\mu)^2}{2\sigma^2}}\end{pmatrix}}\end{bmatrix}
# \\
# \\
# = n \ln{\begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}} -\Sigma_i^n \frac{(y_i-\mu)^2}{2\sigma^2}
# \\
# \\
# \frac{d(\ln{\Pi_i^n (f(y_i))})}{y} = \frac{d}{dy} \begin{bmatrix} n \ln{\begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}} -\Sigma_i^n \frac{(y_i-\mu)^2}{2\sigma^2}\end{bmatrix}
# \\
# \\
# = \frac{d}{dy} n \ln{\begin{pmatrix}\frac{1}{\sigma \sqrt{2 \pi}}\end{pmatrix}} - \frac{d}{dy} \Sigma_i^n \frac{( y_i- \mu)^2}{2\sigma^2}
# \\
# \\
# = 0 - \Sigma_i^n \frac{d}{dy} \frac{( y_i- \mu)^2}{2\sigma^2}
# \\
# \\
# = - \frac{1}{2\sigma^2} \Sigma_i^n \frac{d}{dy} (y_i- \mu)^2
# \\
# \\
# = - \frac{1}{2\sigma^2} \Sigma_i^n 2 (y_i- \mu) \frac{\partial(y_i- \mu)}{\partial(y)}
# \\
# \\
# = - \frac{1}{2\sigma^2} \Sigma_i^n 2 (y_i- \mu)
# \\
# \\
# = - \frac{2}{2\sigma^2}  (\Sigma_i^n y_i- \Sigma_i^n \mu)
# \\
# \\
# = - \frac{1}{\sigma^2}  (\Sigma_i^n y_i- n \mu)
# \\
# \\
# \frac{d(\ln{\Pi_i^n (f(y_i))})}{y} = 0 = - \frac{1}{\sigma^2}  (\Sigma_i^n y_i- n \mu)
# \\
# \\
# 0 = - \frac{1}{\sigma^2}  (\Sigma_i^n y_i- n \mu)
# \\
# \\
# 0 = (\Sigma_i^n y_i- n \mu)
# \\
# \\
# - \Sigma_i^n y_i = - n \mu
# \\
# \\
# \frac{\Sigma_i^n y_i}{n} = \mu
# \end{gather}

# %%
from scipy.stats import norm
import numpy as np
pio.renderers.default = 'iframe'
import plotly
import plotly.graph_objects as go

#creating an array of values between
#-3 to 8 with a difference of 0.1
x = np.arange(-3, 3.5, 0.1)
   
y = norm.pdf(x, 0, 1)

fig = go.Figure([go.Bar(x=x, y=y)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_7.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Gamma Distribution}$
#
# - When the random variable $Y$ is always positive and always skewed to the right.
#
# - Most of the area of the PDF is located near the origin, and the PDF drops gradually as y increases.
#
# - A random variable $Y$ has a gamma distributions with parameters $\alpha>0$ and $\beta>0$ $\iff$
#
# \begin{gather}
# f(y) = \begin{cases}
#       \frac{y^{\alpha-1}e^{\frac{-y}{\beta}}}{\beta^{\alpha} \Gamma(\alpha)}, & \text{if}\ 0\leq y < \infty \\
#       0, & \text{otherwise}
#     \end{cases}
# \end{gather}
#
# If $\alpha \in \mathbb{R^+} >0$:
#
# \begin{gather}
# \Gamma(\alpha) = \int_0^\infty y^{\alpha-1}e^{-y} dy
# \end{gather}
#
# If $\alpha \in \mathbb{Z^+} >0$:
#
# \begin{gather}
# \Gamma(\alpha) = (\alpha-1)!
# \end{gather}
#
# - $E[Y] = \alpha \beta$
#
# - $V[Y] = \alpha \beta^2$

# %%
from scipy.stats import gamma
import numpy as np
import plotly
import plotly.graph_objects as go

#creating an array of values between
#-3 to 8 with a difference of 0.1
x = np.arange(0.1, 10, 0.1)
   
y = gamma.pdf(x, 3, 0.1)

fig = go.Figure([go.Bar(x=x, y=y)])
fig.update_layout(height = 500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Exponential Distribution}$
#
# - For a Gamma distribution with $\alpha = 1$.
#
# \begin{gather}
# f(y) = \begin{cases}
#       \frac{e^{\frac{-y}{\beta}}}{\beta}, & \text{if}\ 0\leq y < \infty \\
#       0, & \text{otherwise}
#     \end{cases}
# \end{gather}
#
# - $E[Y] = \beta$
#
# - $V[Y] = \beta^2$

# %% [markdown]
# $\textbf{Beta Distribution}$
#
# - For random variables $Y$ with limits $0 \leq y \leq 1$.
#
# - Used to model proportions.
#
# - A random variable $Y$ has a beta distribution with parameters $\alpha > 0$ and $\beta >0$ $\iff$
# \begin{gather}
# f(y) = \begin{cases}
#       \frac{y^{\alpha-1}(1-y)^{\beta-1}}{\beta eta(\alpha, \beta)}, & \text{if}\ 0\leq y < \infty \\
#       0, & \text{otherwise}
#     \end{cases}
# \end{gather}
#
# where:
#
# \begin{gather}
# \beta eta(\alpha, \beta) = \frac{\Gamma(\alpha) \Gamma(\beta)}{\Gamma(\alpha + \beta)}
# \end{gather}
#
# - $E[Y] = \frac{\alpha}{\alpha + \beta}$
#
# - $E[Y] = \frac{\alpha \beta}{(\alpha + \beta)^2 (\alpha + \beta +1)}$

# %% [markdown]
# $\textbf{Correlation}$
#
# - Given two i.i.d random variables $x$ and $y$.
#
# \begin{gather}
# r = \frac{\Sigma_i^n (x_i - E[X])(y_i - E[Y])}{\sqrt{\Sigma_i^n (x_i - E[X])^2 (y_i - E[Y])^2}}
# \end{gather}
#
# - The degree of association between two variables.
#
# - The correlation coefficient is measured on a scale that varies from + 1 through 0 to – 1.
#
# - Complete absence of correlation is represented by 0.

# %%
from sklearn.datasets import load_wine
import pandas as pd

# Load the iris dataset from sklearn
wine = load_wine()

# Convert the iris dataset to a pandas dataframe
df = pd.DataFrame(wine.data, columns=wine.feature_names)

# Add the target variable to the dataframe
#df['target'] = iris.target
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
import plotly.express as px
# Correlation
df_corr = df.corr().round(1)  
# Mask to matrix
mask = np.zeros_like(df_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# Viz
df_corr_viz = df_corr.mask(mask).dropna(how='all').dropna('columns', how='all')
fig = px.imshow(df_corr_viz, text_auto=True)
fig.update_layout(height = 900, width=900)
fig.show()
# Out:
# C:\Users\Ralph\AppData\Local\Temp\ipykernel_21500\251590823.py:8: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
# <iframe
#     scrolling="no"
#     width="920px"
#     height="920"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.graph_objects as go

fig = go.Figure()
for i in df.columns:
    fig.add_trace(go.Box(y=df[str(i)], name=str(i)))
fig.update_layout(showlegend=False,height = 700, width=800)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="720"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
standard = (df-df.mean())/df.std()

fig = go.Figure()
for i in standard.columns:
    fig.add_trace(go.Box(y=standard[str(i)], name=str(i)))
fig.update_layout(showlegend=False,height = 700, width=800)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="720"
#     src="iframe_figures/figure_12.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.express as px
# Correlation
std_corr = standard.corr().round(1)  
# Mask to matrix
mask = np.zeros_like(std_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# Viz
df_corr_viz = std_corr.mask(mask).dropna(how='all').dropna('columns', how='all')
fig = px.imshow(df_corr_viz, text_auto=True)
fig.update_layout(height = 900, width=900)
fig.show()
# Out:
# C:\Users\Ralph\AppData\Local\Temp\ipykernel_21500\2528209976.py:8: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
# <iframe
#     scrolling="no"
#     width="920px"
#     height="920"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# $\textbf{Statistical Inference}$
#
# - Statistical inference is the process of drawing conclusions about an underlying population based on a sample or subset of the data.
#
# - In most cases, it is not practical to obtain all the measurements in a given population. So get a randomly collected sample determine its parameter and infer if this parameter is a true representative of the population.
#
# $\textbf{P-Value}$
# - It just tells you how likely you’d see the data you observed (or more extreme data) if the null hypothesis was true. It’s a piece of evidence, not a definitive proof.
#
# - The null hypothesis is always the "no effect".
#
# - Example: Suppose you’re conducting a study to determine whether a new drug has an effect on pain relief compared to a placebo. If the new drug has no impact, your test statistic will be close to the one predicted by the null hypothesis (no difference between the drug and placebo groups), and the resulting p-value will be close to 1.
#
# - Errors in statistical inference:
#
# \begin{gather}
# \begin{bmatrix}
# Decision & H_0 \ is \ True & H_0 \ is \ False \\
# Rejected \ H_0 & Type I Error & Correct \ Decision \\
# Accpeted \ H_0 & Correct \ Decision & Type II Error \\
# \end{bmatrix}
# \end{gather}

# %% [markdown]
# $\textbf{Different Kinds of Tests}$:
#
# 1. Paired T-Test:
#
# - Used for before and after experiments, example you want to compare the same person before and after a treatment.
#
# - Assumption is data should be normally distributed, and samples must be independent of each other.
#
# 2. Unpaired T-Test:
#
# - Used to compared two samples, example you want to compare student performance between synch and asynch classes.
#
# - Assumption is data should be normally distributed.
#
# 3. $\chi^2$ Test for Goodness of Fit:
#
# - Tests if the observed and the actual distributions are the same.
#
# - Assumption that data must be categorical with at least 5 categories, and sampled must be independent of each other.
#
# 4. $\chi^2$ Test for Homogeniety:
#
# - Used to test a single categorical variable from two samples.
#
# - Assumption that data must be categorical and sampled must be independent of each other.
#
# 5. $\chi^2$ Test for Independence:
#
# - Used to test two categorical variables from the same samples.
#
# - Assumption that data must be categorical.
#
# 6. ANOVA
#
# - Analysis tool used in statistics that splits an observed aggregate variability found inside a data set into two parts: systematic factors and random factors. The systematic factors have a statistical influence on the given data set, while the random factors do not.
#
# - Types I, II and III.

# %% [markdown]
# $\textbf{PROGRAMMING ASSIGNMENT}$
# ---
#
# Data: https://archive.ics.uci.edu
#
# Instructions: Choose a dataset of your liking and perform the following:
#
# 1. Create a Correlation Plot
#
# 2. Check the distribution of each column and determine which probability distiribution it fits.
#
# 3. Create a summary statistics.
#
# 4. Perform a hypothesis test (Code from scratch).

# %%
pip install pandas numpy seaborn scipy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('OnlineNewsPopularity.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(15, 10))

# Draw the heatmap
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')

plt.title('Correlation Matrix of Online News Popularity Dataset')
plt.show()
# Out:
# C:\Users\Ralph\AppData\Local\Temp\ipykernel_21500\429555386.py:5: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def plot_distributions(df):
    for column in df.columns:
        plt.figure(figsize=(10, 5))
        sns.histplot(df[column], kde=True)
        plt.title(f'Distribution of {column}')
        plt.show()

plot_distributions(df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 12
#       9         plt.title(f'Distribution of {column}')
#      10         plt.show()
# ---> 12 plot_distributions(df)
#
# Cell In[17], line 8, in plot_distributions(df)
#       6 for column in df.columns:
#       7     plt.figure(figsize=(10, 5))
# ----> 8     sns.histplot(df[column], kde=True)
#       9     plt.title(f'Distribution of {column}')
#      10     plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
#    1436         shrink=shrink,
#    1437         common_norm=common_norm,
#    1438         common_bins=common_bins,
#    1439         kde=kde,
#    1440         kde_kws=kde_kws,
#    1441         color=color,
#    1442         legend=legend,
#    1443         estimate_kws=estimate_kws,
#    1444         line_kws=line_kws,
#    1445         **kwargs,
#    1446     )
#    1448 else:
#    1450     p.plot_bivariate_histogram(
#    1451         common_bins=common_bins,
#    1452         common_norm=common_norm,
#    (...)
#    1462         **kwargs,
#    1463     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\distributions.py:475, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     473 # Do the histogram computation
#     474 if not (multiple_histograms and common_bins):
# --> 475     bin_kws = estimator._define_bin_params(sub_data, orient, None)
#     476 res = estimator._normalize(estimator._eval(sub_data, orient, bin_kws))
#     477 heights = res[estimator.stat].to_numpy()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_stats\counting.py:152, in Hist._define_bin_params(self, data, orient, scale_type)
#     148 # TODO We'll want this for ordinal / discrete scales too
#     149 # (Do we need discrete as a parameter or just infer from scale?)
#     150 discrete = self.discrete or scale_type == "nominal"
# --> 152 bin_edges = self._define_bin_edges(
#     153     vals, weights, self.bins, self.binwidth, self.binrange, discrete,
#     154 )
#     156 if isinstance(self.bins, (str, int)):
#     157     n_bins = len(bin_edges) - 1
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_stats\counting.py:137, in Hist._define_bin_edges(self, vals, weight, bins, binwidth, binrange, discrete)
#     135     bin_edges = np.arange(start, stop + step, step)
#     136 else:
# --> 137     bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
#     139 # TODO warning or cap on too many bins?
#     141 return bin_edges
#
# File <__array_function__ internals>:200, in histogram_bin_edges(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\histograms.py:669, in histogram_bin_edges(a, bins, range, weights)
#     472 r"""
#     473 Function to calculate only the edges of the bins used by the `histogram`
#     474 function.
#    (...)
#     666
#     667 """
#     668 a, weights = _ravel_and_check_weights(a, weights)
# --> 669 bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     670 return bin_edges
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\histograms.py:446, in _get_bin_edges(a, bins, range, weights)
#     443         bin_type = np.result_type(bin_type, float)
#     445     # bin edges must be computed
# --> 446     bin_edges = np.linspace(
#     447         first_edge, last_edge, n_equal_bins + 1,
#     448         endpoint=True, dtype=bin_type)
#     449     return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450 else:
#
# File <__array_function__ internals>:200, in linspace(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\function_base.py:139, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     136     integer_dtype = _nx.issubdtype(dtype, _nx.integer)
#     138 delta = stop - start
# --> 139 y = _nx.arange(0, num, dtype=dt).reshape((-1,) + (1,) * ndim(delta))
#     140 # In-place multiplication y *= delta/div is faster, but prevents the multiplicant
#     141 # from overriding what class is produced, and thus prevents, e.g. use of Quantities,
#     142 # see gh-7142. Hence, we multiply in place only for standard scalar types.
#     143 if div > 0:
#
# MemoryError: Unable to allocate 30.0 TiB for an array with shape (4117972210849,) and data type float64

# %%
def fit_distribution(data):
    # Filter non-numeric and non-finite values
    data = data[np.isfinite(data)]
    
    # Define the distributions to check
    distributions = [stats.norm, stats.expon, stats.lognorm]
    best_fit_name = None
    best_fit_params = None
    best_sse = np.inf

    for distribution in distributions:
        # Fit the distribution to the data
        params = distribution.fit(data)
        arg = params[:-2]
        loc = params[-2]
        scale = params[-1]

        # Define the range for the PDF calculation
        x = np.linspace(np.min(data), np.max(data), len(data))
        pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)

        # Calculate the sum of squared errors
        sse = np.sum(np.power(data - pdf, 2.0))

        if best_sse > sse:
            best_fit_name = distribution.name
            best_fit_params = params
            best_sse = sse

    return best_fit_name, best_fit_params

# Load the dataset
df = pd.read_csv('OnlineNewsPopularity.csv')

# Example usage:
for column in df.columns:
    # Only fit distributions to numeric columns
    if pd.api.types.is_numeric_dtype(df[column]):
        best_fit, params = fit_distribution(df[column].dropna())
        print(f'Best fit for {column}: {best_fit} with parameters {params}')
# Out:
# Best fit for  timedelta: expon with parameters (8.0, 346.53047119362327)
# Best fit for  n_tokens_title: norm with parameters (10.398748864897588, 2.1140101453767435)
# Best fit for  n_tokens_content: expon with parameters (0.0, 546.514731106851)
# Best fit for  n_unique_tokens: norm with parameters (0.5482157168486131, 3.5206639269108986)
# Best fit for  n_non_stop_words: expon with parameters (0.0, 0.9964685654578609)
# Best fit for  n_non_stop_unique_tokens: norm with parameters (0.6891753940079294, 3.2647751778770817)
# Best fit for  num_hrefs: expon with parameters (0.0, 10.883689839572192)
# Best fit for  num_self_hrefs: expon with parameters (0.0, 3.2936383815962063)
# Best fit for  num_imgs: expon with parameters (0.0, 4.544142871556856)
# Best fit for  num_videos: norm with parameters (1.2498738775098375, 4.107803276605684)
# Best fit for  average_token_length: lognorm with parameters (0.0007926711767743428, -1062.2289801268744, 1066.7708624848522)
# Best fit for  num_keywords: lognorm with parameters (0.007701514168899928, -240.0410545798593, 247.25558858475188)
# Best fit for  data_channel_is_lifestyle: norm with parameters (0.05294622137019473, 0.22392614633582447)
# Best fit for  data_channel_is_entertainment: norm with parameters (0.17800928261527596, 0.38252055881752395)
# Best fit for  data_channel_is_bus: norm with parameters (0.15785490868731714, 0.3646049046442408)
# Best fit for  data_channel_is_socmed: norm with parameters (0.0585965089294723, 0.2348679587997277)
# Best fit for  data_channel_is_tech: norm with parameters (0.1852991625466653, 0.3885400660243031)
# Best fit for  data_channel_is_world: norm with parameters (0.21256684491978609, 0.409123674896276)
# Best fit for  kw_min_min: expon with parameters (-1.0, 27.10680052466956)
# Best fit for  kw_max_min: expon with parameters (0.0, 1153.9516822217738)
# Best fit for  kw_avg_min: lognorm with parameters (0.6401335313596417, -59.5013808418095, 289.4312153134425)
# Best fit for  kw_min_max: norm with parameters (13612.35410150338, 57985.29801851816)
# Best fit for  kw_max_max: norm with parameters (752324.0666935728, 214499.42420143142)
# Best fit for  kw_avg_max: norm with parameters (259281.93808264728, 135100.5433308444)
# Best fit for  kw_min_avg: expon with parameters (-1.0, 1118.1466099698362)
# Best fit for  kw_max_avg: expon with parameters (0.0, 5657.211151064957)
# Best fit for  kw_avg_avg: norm with parameters (3135.8586389465236, 1318.1337721478328)
# Best fit for  self_reference_min_shares: lognorm with parameters (5.341539133117658, -7.24182707792267e-06, 195.61914821377843)
# Best fit for  self_reference_max_shares: expon with parameters (0.0, 10329.212661941277)
# Best fit for  self_reference_avg_sharess: expon with parameters (0.0, 6401.697579821467)
# Best fit for  weekday_is_monday: norm with parameters (0.16802038139441025, 0.37388438430949106)
# Best fit for  weekday_is_tuesday: norm with parameters (0.18640904046009485, 0.3894364005776059)
# Best fit for  weekday_is_wednesday: norm with parameters (0.18754414287155685, 0.3903477133865778)
# Best fit for  weekday_is_thursday: norm with parameters (0.18330642720209867, 0.3869175376595126)
# Best fit for  weekday_is_friday: norm with parameters (0.14380486328322067, 0.35089175621452673)
# Best fit for  weekday_is_saturday: norm with parameters (0.06187569367369589, 0.2409296416095264)
# Best fit for  weekday_is_sunday: norm with parameters (0.06903945111492281, 0.2535212127311499)
# Best fit for  is_weekend: norm with parameters (0.1309151447886187, 0.337307529790833)
# Best fit for  LDA_00: norm with parameters (0.18459904828385124, 0.26297139241006023)
# Best fit for  LDA_01: norm with parameters (0.1412557731283032, 0.2197045578256522)
# Best fit for  LDA_02: norm with parameters (0.21632096677306634, 0.2821416453823548)
# Best fit for  LDA_03: norm with parameters (0.22376961651356772, 0.2951870104354919)
# Best fit for  LDA_04: norm with parameters (0.2340293708031828, 0.28917983080444787)
# Best fit for  global_subjectivity: expon with parameters (0.0, 0.443370199550738)
# Best fit for  global_sentiment_polarity: expon with parameters (-0.39375, 0.5130592692857174)
# Best fit for  global_rate_positive_words: expon with parameters (0.0, 0.039624833009040954)
# Best fit for  global_rate_negative_words: norm with parameters (0.016612119534643015, 0.010827655624179177)
# Best fit for  rate_positive_words: expon with parameters (0.0, 0.6821502211003009)
# Best fit for  rate_negative_words: expon with parameters (0.0, 0.2879335242331674)
# Best fit for  avg_positive_polarity: expon with parameters (0.0, 0.35382494340707155)
# Best fit for  min_positive_polarity: norm with parameters (0.09544553807024497, 0.07131403229835133)
# Best fit for  max_positive_polarity: expon with parameters (0.0, 0.7567275436995321)
# Best fit for  avg_negative_polarity: expon with parameters (-1.0, 0.7404758589090819)
# Best fit for  min_negative_polarity: norm with parameters (-0.5219437277484054, 0.29028584098280874)
# Best fit for  max_negative_polarity: expon with parameters (-1.0, 0.8924997598436551)
# Best fit for  title_subjectivity: norm with parameters (0.2823531841135628, 0.32424328577490374)
# Best fit for  title_sentiment_polarity: expon with parameters (-1.0, 1.0714254319759355)
# Best fit for  abs_title_subjectivity: norm with parameters (0.34184275596034774, 0.1887884236613383)
# Best fit for  abs_title_sentiment_polarity: norm with parameters (0.1560636628565405, 0.2262913436293084)
# Best fit for  shares: expon with parameters (1.0, 3394.3801836343455)

# %%
summary_statistics = df.describe()
print(summary_statistics)
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# 50%             1.000000                   0.690476      8.000000
# 75%             1.000000                   0.754630     14.000000
# max          1042.000000                 650.000000    304.000000
#
#         num_self_hrefs      num_imgs    num_videos  ...  \
# count     39644.000000  39644.000000  39644.000000  ...
# mean          3.293638      4.544143      1.249874  ...
# std           3.855141      8.309434      4.107855  ...
# min           0.000000      0.000000      0.000000  ...
# 25%           1.000000      1.000000      0.000000  ...
# 50%           3.000000      1.000000      0.000000  ...
# 75%           4.000000      4.000000      1.000000  ...
# max         116.000000    128.000000     91.000000  ...
#
#         min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# count            39644.000000            39644.000000            39644.000000
# mean                 0.095446                0.756728               -0.259524
# std                  0.071315                0.247786                0.127726
# min                  0.000000                0.000000               -1.000000
# 25%                  0.050000                0.600000               -0.328383
# 50%                  0.100000                0.800000               -0.253333
# 75%                  0.100000                1.000000               -0.186905
# max                  1.000000                1.000000                0.000000
#
#         min_negative_polarity   max_negative_polarity   title_subjectivity  \
# count            39644.000000            39644.000000         39644.000000
# mean                -0.521944               -0.107500             0.282353
# std                  0.290290                0.095373             0.324247
# min                 -1.000000               -1.000000             0.000000
# 25%                 -0.700000               -0.125000             0.000000
# 50%                 -0.500000               -0.100000             0.150000
# 75%                 -0.300000               -0.050000             0.500000
# max                  0.000000                0.000000             1.000000
#
#         title_sentiment_polarity   abs_title_subjectivity  \
# count               39644.000000             39644.000000
# mean                    0.071425                 0.341843
# std                     0.265450                 0.188791
# min                    -1.000000                 0.000000
# 25%                     0.000000                 0.166667
# 50%                     0.000000                 0.500000
# 75%                     0.150000                 0.500000
# max                     1.000000                 0.500000
#
#         abs_title_sentiment_polarity         shares
# count                   39644.000000   39644.000000
# mean                        0.156064    3395.380184
# std                         0.226294   11626.950749
# min                         0.000000       1.000000
# 25%                         0.000000     946.000000
# 50%                         0.000000    1400.000000
# 75%                         0.250000    2800.000000
# max                         1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
print(df.columns)
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
#        ' LDA_03', ' LDA_04', ' global_subjectivity',
#        ' global_sentiment_polarity', ' global_rate_positive_words',
#        ' global_rate_negative_words', ' rate_positive_words',
#        ' rate_negative_words', ' avg_positive_polarity',
#        ' min_positive_polarity', ' max_positive_polarity',
#        ' avg_negative_polarity', ' min_negative_polarity',
#        ' max_negative_polarity', ' title_subjectivity',
#        ' title_sentiment_polarity', ' abs_title_subjectivity',
#        ' abs_title_sentiment_polarity', ' shares'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

def t_test(column1, column2):
    data1 = df[column1].dropna()
    data2 = df[column2].dropna()

    n1, n2 = len(data1), len(data2)
    mean1, mean2 = np.mean(data1), np.mean(data2)
    var1, var2 = np.var(data1, ddof=1), np.var(data2, ddof=1)

    pooled_var = (((n1 - 1) * var1) + ((n2 - 1) * var2)) / (n1 + n2 - 2)
    t_stat = (mean1 - mean2) / np.sqrt(pooled_var * (1/n1 + 1/n2))
    
    df_degrees_of_freedom = n1 + n2 - 2
    p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df_degrees_of_freedom))

    return t_stat, p_value

# Perform the t-test
t_stat, p_value = t_test('n_tokens_title', 'n_tokens_content')

# Print the results
print(f'T-statistic: {t_stat}, P-value: {p_value}')

# Interpret the result
if p_value < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# T-statistic: -226.58079166072017, P-value: 0.0
# Reject the null hypothesis
